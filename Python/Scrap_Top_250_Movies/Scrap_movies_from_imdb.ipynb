# %% [markdown]
# <a href="https://colab.research.google.com/github/Nagasuruthika/hacking-tools-scripts/blob/new1/Scarp_movies_from_imdb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 from bs4 import BeautifulSoup #imports beautifulsoup to scrap data

# %%
import requests #requests library for getting URL information

# %%
url = 'https://www.imdb.com/chart/top/?ref_=nv_mv_250 '

# %%
resp = requests.get(url) #requests to url for obtaining information

# %%
soup = BeautifulSoup(resp.text)

# %%
lister_list = soup.find('tbody', {'class':'lister-list'}) #body section lies in the lister-list class in the URL

# %%
tr_section = lister_list.findAll('tr') #stores all information of "tr" section

# %%
for tr in tr_section:
  tr.find('td',{'class':'titleColumn'})

# %%
movies=[]
for tr in tr_section:
  title=tr.find('td',{'class':'titleColumn'}).text
  movies.append(title)

# %%
for name in movies:
  print(name)
# Out:
#       1.
#       The Shawshank Redemption
# (1994)
#
#
#       2.
#       The Godfather
# (1972)
#
#
#       3.
#       The Godfather: Part II
# (1974)
#
#
#       4.
#       The Dark Knight
# (2008)
#
#
#       5.
#       12 Angry Men
# (1957)
#
#
#       6.
#       Schindler's List
# (1993)
#
#
#       7.
#       The Lord of the Rings: The Return of the King
# (2003)
#
#
#       8.
#       Pulp Fiction
# (1994)
#
#
#       9.
#       The Good, the Bad and the Ugly
# (1966)
#
#
#       10.
#       The Lord of the Rings: The Fellowship of the Ring
# (2001)
#
#
#       11.
#       Fight Club
# (1999)
#
#
#       12.
#       Forrest Gump
# (1994)
#
#
#       13.
#       Inception
# (2010)
#
#
#       14.
#       The Lord of the Rings: The Two Towers
# (2002)
#
#
#       15.
#       Star Wars: Episode V - The Empire Strikes Back
# (1980)
#
#
#       16.
#       The Matrix
# (1999)
#
#
#       17.
#       Goodfellas
# (1990)
#
#
#       18.
#       One Flew Over the Cuckoo's Nest
# (1975)
#
#
#       19.
#       Seven Samurai
# (1954)
#
#
#       20.
#       Se7en
# (1995)
#
#
#       21.
#       Life Is Beautiful
# (1997)
#
#
#       22.
#       City of God
# (2002)
#
#
#       23.
#       The Silence of the Lambs
# (1991)
#
#
#       24.
#       It's a Wonderful Life
# (1946)
#
#
#       25.
#       Star Wars: Episode IV - A New Hope
# (1977)
#
#
#       26.
#       Saving Private Ryan
# (1998)
#
#
#       27.
#       Spirited Away
# (2001)
#
#
#       28.
#       The Green Mile
# (1999)
#
#
#       29.
#       Parasite
# (2019)
#
#
#       30.
#       Interstellar
# (2014)
#
#
#       31.
#       Léon: The Professional
# (1994)
#
#
#       32.
#       The Usual Suspects
# (1995)
#
#
#       33.
#       Harakiri
# (1962)
#
#
#       34.
#       The Lion King
# (1994)
#
#
#       35.
#       Back to the Future
# (1985)
#
#
#       36.
#       The Pianist
# (2002)
#
#
#       37.
#       Terminator 2: Judgment Day
# (1991)
#
#
#       38.
#       American History X
# (1998)
#
#
#       39.
#       Modern Times
# (1936)
#
#
#       40.
#       Psycho
# (1960)
#
#
#       41.
#       Gladiator
# (2000)
#
#
#       42.
#       City Lights
# (1931)
#
#
#       43.
#       The Departed
# (2006)
#
#
#       44.
#       The Intouchables
# (2011)
#
#
#       45.
#       Whiplash
# (2014)
#
#
#       46.
#       Hamilton
# (2020)
#
#
#       47.
#       The Prestige
# (2006)
#
#
#       48.
#       Grave of the Fireflies
# (1988)
#
#
#       49.
#       Once Upon a Time in the West
# (1968)
#
#
#       50.
#       Casablanca
# (1942)
#
#
#       51.
#       Cinema Paradiso
# (1988)
#
#
#       52.
#       Rear Window
# (1954)
#
#
#       53.
#       Alien
# (1979)
#
#
#       54.
#       Apocalypse Now
# (1979)
#
#
#       55.
#       Memento
# (2000)
#
#
#       56.
#       Raiders of the Lost Ark
# (1981)
#
#
#       57.
#       The Great Dictator
# (1940)
#
#
#       58.
#       Django Unchained
# (2012)
#
#
#       59.
#       The Lives of Others
# (2006)
#
#
#       60.
#       Joker
# (2019)
#
#
#       61.
#       Paths of Glory
# (1957)
#
#
#       62.
#       WALL·E
# (2008)
#
#
#       63.
#       The Shining
# (1980)
#
#
#       64.
#       Avengers: Infinity War
# (2018)
#
#
#       65.
#       Sunset Blvd.
# (1950)
#
#
#       66.
#       Witness for the Prosecution
# (1957)
#
#
#       67.
#       Spider-Man: Into the Spider-Verse
# (2018)
#
#
#       68.
#       Oldboy
# (2003)
#
#
#       69.
#       Princess Mononoke
# (1997)
#
#
#       70.
#       Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
# (1964)
#
#
#       71.
#       The Dark Knight Rises
# (2012)
#
#
#       72.
#       Once Upon a Time in America
# (1984)
#
#
#       73.
#       Aliens
# (1986)
#
#
#       74.
#       Your Name.
# (2016)
#
#
#       75.
#       Avengers: Endgame
# (2019)
#
#
#       76.
#       Coco
# (2017)
#
#
#       77.
#       American Beauty
# (1999)
#
#
#       78.
#       Braveheart
# (1995)
#
#
#       79.
#       3 Idiots
# (2009)
#
#
#       80.
#       Das Boot
# (1981)
#
#
#       81.
#       Toy Story
# (1995)
#
#
#       82.
#       High and Low
# (1963)
#
#
#       83.
#       Amadeus
# (1984)
#
#
#       84.
#       Capharnaüm
# (2018)
#
#
#       85.
#       Taare Zameen Par
# (2007)
#
#
#       86.
#       Inglourious Basterds
# (2009)
#
#
#       87.
#       Star Wars: Episode VI - Return of the Jedi
# (1983)
#
#
#       88.
#       Reservoir Dogs
# (1992)
#
#
#       89.
#       Good Will Hunting
# (1997)
#
#
#       90.
#       2001: A Space Odyssey
# (1968)
#
#
#       91.
#       Requiem for a Dream
# (2000)
#
#
#       92.
#       Vertigo
# (1958)
#
#
#       93.
#       M
# (1931)
#
#
#       94.
#       Eternal Sunshine of the Spotless Mind
# (2004)
#
#
#       95.
#       Dangal
# (2016)
#
#
#       96.
#       The Hunt
# (2012)
#
#
#       97.
#       Citizen Kane
# (1941)
#
#
#       98.
#       1917
# (2019)
#
#
#       99.
#       Full Metal Jacket
# (1987)
#
#
#       100.
#       Bicycle Thieves
# (1948)
#
#
#       101.
#       The Kid
# (1921)
#
#
#       102.
#       Singin' in the Rain
# (1952)
#
#
#       103.
#       A Clockwork Orange
# (1971)
#
#
#       104.
#       North by Northwest
# (1959)
#
#
#       105.
#       Snatch
# (2000)
#
#
#       106.
#       Scarface
# (1983)
#
#
#       107.
#       Taxi Driver
# (1976)
#
#
#       108.
#       Ikiru
# (1952)
#
#
#       109.
#       Lawrence of Arabia
# (1962)
#
#
#       110.
#       Amélie
# (2001)
#
#
#       111.
#       Toy Story 3
# (2010)
#
#
#       112.
#       The Sting
# (1973)
#
#
#       113.
#       Metropolis
# (1927)
#
#
#       114.
#       A Separation
# (2011)
#
#
#       115.
#       Incendies
# (2010)
#
#
#       116.
#       For a Few Dollars More
# (1965)
#
#
#       117.
#       Come and See
# (1985)
#
#
#       118.
#       The Apartment
# (1960)
#
#
#       119.
#       Double Indemnity
# (1944)
#
#
#       120.
#       To Kill a Mockingbird
# (1962)
#
#
#       121.
#       Up
# (2009)
#
#
#       122.
#       Indiana Jones and the Last Crusade
# (1989)
#
#
#       123.
#       L.A. Confidential
# (1997)
#
#
#       124.
#       Heat
# (1995)
#
#
#       125.
#       Die Hard
# (1988)
#
#
#       126.
#       Monty Python and the Holy Grail
# (1975)
#
#
#       127.
#       Rashômon
# (1950)
#
#
#       128.
#       Yojimbo
# (1961)
#
#
#       129.
#       Batman Begins
# (2005)
#
#
#       130.
#       Green Book
# (2018)
#
#
#       131.
#       Downfall
# (2004)
#
#
#       132.
#       Children of Heaven
# (1997)
#
#
#       133.
#       Unforgiven
# (1992)
#
#
#       134.
#       Ran
# (1985)
#
#
#       135.
#       Some Like It Hot
# (1959)
#
#
#       136.
#       Howl's Moving Castle
# (2004)
#
#
#       137.
#       A Beautiful Mind
# (2001)
#
#
#       138.
#       All About Eve
# (1950)
#
#
#       139.
#       Casino
# (1995)
#
#
#       140.
#       The Great Escape
# (1963)
#
#
#       141.
#       The Wolf of Wall Street
# (2013)
#
#
#       142.
#       Pan's Labyrinth
# (2006)
#
#
#       143.
#       Anand
# (1971)
#
#
#       144.
#       The Secret in Their Eyes
# (2009)
#
#
#       145.
#       Lock, Stock and Two Smoking Barrels
# (1998)
#
#
#       146.
#       Raging Bull
# (1980)
#
#
#       147.
#       My Neighbor Totoro
# (1988)
#
#
#       148.
#       There Will Be Blood
# (2007)
#
#
#       149.
#       Judgment at Nuremberg
# (1961)
#
#
#       150.
#       The Treasure of the Sierra Madre
# (1948)
#
#
#       151.
#       Three Billboards Outside Ebbing, Missouri
# (2017)
#
#
#       152.
#       Dial M for Murder
# (1954)
#
#
#       153.
#       Chinatown
# (1974)
#
#
#       154.
#       The Gold Rush
# (1925)
#
#
#       155.
#       Babam ve Oglum
# (2005)
#
#
#       156.
#       Vikram Vedha
# (2017)
#
#
#       157.
#       Shutter Island
# (2010)
#
#
#       158.
#       No Country for Old Men
# (2007)
#
#
#       159.
#       V for Vendetta
# (2005)
#
#
#       160.
#       The Seventh Seal
# (1957)
#
#
#       161.
#       Inside Out
# (2015)
#
#
#       162.
#       Warrior
# (2011)
#
#
#       163.
#       The Elephant Man
# (1980)
#
#
#       164.
#       The Thing
# (1982)
#
#
#       165.
#       The Sixth Sense
# (1999)
#
#
#       166.
#       Trainspotting
# (1996)
#
#
#       167.
#       Jurassic Park
# (1993)
#
#
#       168.
#       Gone with the Wind
# (1939)
#
#
#       169.
#       The Truman Show
# (1998)
#
#
#       170.
#       Wild Strawberries
# (1957)
#
#
#       171.
#       Finding Nemo
# (2003)
#
#
#       172.
#       Blade Runner
# (1982)
#
#
#       173.
#       Stalker
# (1979)
#
#
#       174.
#       Kill Bill: Vol. 1
# (2003)
#
#
#       175.
#       Room
# (2015)
#
#
#       176.
#       The Bridge on the River Kwai
# (1957)
#
#
#       177.
#       Fargo
# (1996)
#
#
#       178.
#       Memories of Murder
# (2003)
#
#
#       179.
#       Tokyo Story
# (1953)
#
#
#       180.
#       The Third Man
# (1949)
#
#
#       181.
#       Gran Torino
# (2008)
#
#
#       182.
#       On the Waterfront
# (1954)
#
#
#       183.
#       Wild Tales
# (2014)
#
#
#       184.
#       The Deer Hunter
# (1978)
#
#
#       185.
#       Klaus
# (2019)
#
#
#       186.
#       In the Name of the Father
# (1993)
#
#
#       187.
#       Mary and Max
# (2009)
#
#
#       188.
#       Gone Girl
# (2014)
#
#
#       189.
#       Andhadhun
# (2018)
#
#
#       190.
#       The Grand Budapest Hotel
# (2014)
#
#
#       191.
#       Hacksaw Ridge
# (2016)
#
#
#       192.
#       Before Sunrise
# (1995)
#
#
#       193.
#       Catch Me If You Can
# (2002)
#
#
#       194.
#       The Big Lebowski
# (1998)
#
#
#       195.
#       Persona
# (1966)
#
#
#       196.
#       To Be or Not to Be
# (1942)
#
#
#       197.
#       Prisoners
# (2013)
#
#
#       198.
#       The Bandit
# (1996)
#
#
#       199.
#       Sherlock Jr.
# (1924)
#
#
#       200.
#       The General
# (1926)
#
#
#       201.
#       Ford v Ferrari
# (2019)
#
#
#       202.
#       How to Train Your Dragon
# (2010)
#
#
#       203.
#       Mr. Smith Goes to Washington
# (1939)
#
#
#       204.
#       12 Years a Slave
# (2013)
#
#
#       205.
#       Barry Lyndon
# (1975)
#
#
#       206.
#       Mad Max: Fury Road
# (2015)
#
#
#       207.
#       Million Dollar Baby
# (2004)
#
#
#       208.
#       Stand by Me
# (1986)
#
#
#       209.
#       Network
# (1976)
#
#
#       210.
#       Cool Hand Luke
# (1967)
#
#
#       211.
#       Dead Poets Society
# (1989)
#
#
#       212.
#       Ben-Hur
# (1959)
#
#
#       213.
#       Hachi: A Dog's Tale
# (2009)
#
#
#       214.
#       Harry Potter and the Deathly Hallows: Part 2
# (2011)
#
#
#       215.
#       Platoon
# (1986)
#
#
#       216.
#       Into the Wild
# (2007)
#
#
#       217.
#       Logan
# (2017)
#
#
#       218.
#       Monty Python's Life of Brian
# (1979)
#
#
#       219.
#       The Wages of Fear
# (1953)
#
#
#       220.
#       Rush
# (2013)
#
#
#       221.
#       The Handmaiden
# (2016)
#
#
#       222.
#       The Passion of Joan of Arc
# (1928)
#
#
#       223.
#       The 400 Blows
# (1959)
#
#
#       224.
#       Andrei Rublev
# (1966)
#
#
#       225.
#       Hotel Rwanda
# (2004)
#
#
#       226.
#       Spotlight
# (2015)
#
#
#       227.
#       Amores Perros
# (2000)
#
#
#       228.
#       Rififi
# (1955)
#
#
#       229.
#       La Haine
# (1995)
#
#
#       230.
#       Nausicaä of the Valley of the Wind
# (1984)
#
#
#       231.
#       Gangs of Wasseypur
# (2012)
#
#
#       232.
#       Rocky
# (1976)
#
#
#       233.
#       Monsters, Inc.
# (2001)
#
#
#       234.
#       Rebecca
# (1940)
#
#
#       235.
#       Rang De Basanti
# (2006)
#
#
#       236.
#       Before Sunset
# (2004)
#
#
#       237.
#       Portrait of a Lady on Fire
# (2019)
#
#
#       238.
#       In the Mood for Love
# (2000)
#
#
#       239.
#       Paris, Texas
# (1984)
#
#
#       240.
#       It Happened One Night
# (1934)
#
#
#       241.
#       Drishyam
# (2015)
#
#
#       242.
#       The Invisible Guest
# (2016)
#
#
#       243.
#       The Help
# (2011)
#
#
#       244.
#       The Princess Bride
# (1987)
#
#
#       245.
#       The Circus
# (1928)
#
#
#       246.
#       The Battle of Algiers
# (1966)
#
#
#       247.
#       The Terminator
# (1984)
#
#
#       248.
#       Aladdin
# (1992)
#
#
#       249.
#       Tangerines
# (2013)
#
#
#       250.
#       A Silent Voice: The Movie
# (2016)

# %%
import pandas as pd   
df = pd.DataFrame(movies)

# %%
df.to_csv('Top250.csv')

# %%
pd.read_csv("Top250.csv")
# Out:
#      Unnamed: 0                                                  0
# 0             0  \n      1.\n      The Shawshank Redemption\n(1...
# 1             1          \n      2.\n      The Godfather\n(1972)\n
# 2             2  \n      3.\n      The Godfather: Part II\n(197...
# 3             3        \n      4.\n      The Dark Knight\n(2008)\n
# 4             4           \n      5.\n      12 Angry Men\n(1957)\n
# ..          ...                                                ...
# 245         245  \n      246.\n      The Battle of Algiers\n(19...
# 246         246       \n      247.\n      The Terminator\n(1984)\n
# 247         247              \n      248.\n      Aladdin\n(1992)\n
# 248         248           \n      249.\n      Tangerines\n(2013)\n
# 249         249  \n      250.\n      A Silent Voice: The Movie\...
#
# [250 rows x 2 columns]
